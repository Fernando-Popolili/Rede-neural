# %%
from sklearn.datasets import load_breast_cancer
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Carregar dados
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name='target')

# Criar modelo Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# RFE - selecionar 10 melhores features
rfe_rf = RFE(estimator=rf_model, n_features_to_select=10, step=1)
rfe_rf.fit(X, y)

# Resultados RFE
resultados_rfe = pd.DataFrame({
    'Feature': X.columns,
    'Ranking': rfe_rf.ranking_,
    'Selecionada': rfe_rf.support_
}).sort_values('Ranking')

print(resultados_rfe)
# Out:
#                     Feature  Ranking  Selecionada
# 3                 mean area        1         True
# 2            mean perimeter        1         True
# 6            mean concavity        1         True
# 7       mean concave points        1         True
# 20             worst radius        1         True
# 21            worst texture        1         True
# 22          worst perimeter        1         True
# 23               worst area        1         True
# 27     worst concave points        1         True
# 26          worst concavity        1         True
# 24         worst smoothness        2        False
# 0               mean radius        3        False
# 13               area error        4        False
# 1              mean texture        5        False
# 25        worst compactness        6        False
# 10             radius error        7        False
# 28           worst symmetry        8        False
# 5          mean compactness        9        False
# 4           mean smoothness       10        False
# 29  worst fractal dimension       11        False
# 12          perimeter error       12        False
# 16          concavity error       13        False
# 15        compactness error       14        False
# 14         smoothness error       15        False
# 18           symmetry error       16        False
# 17     concave points error       17        False
# 19  fractal dimension error       18        False
# 11            texture error       19        False
# 8             mean symmetry       20        False
# 9    mean fractal dimension       21        False
